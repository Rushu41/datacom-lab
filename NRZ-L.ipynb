# %% [markdown]
# <h1>NRZ-L Encoding and Decoding
# </h1>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bits ='10111001'

# %% [markdown]
# <h3>Encoding NRZ-L<h3>

# %%
encode = ''
x = '1' 
for i in bits:
    if i == '1':
        encode += '1'
    else:
        encode += '0'
print(encode)
# Out:
# 10111001

# %% [markdown]
# <h3>Decoding NRZ-I<h3>

# %%
decode = ''
x = '1' 
for i in encode:
    if i == '1':
        decode += '1'
    else:
        decode += '0'
print(decode)
# Out:
# 10111001

# %%
encode_arr = np.array([int(i) for i in encode])
decode_arr = np.array([int(i) for i in decode])

# %% [markdown]
# <h3>Check if bits and decode are same or not</h3>

# %%
decode == bits
# Out:
# True

# %% [markdown]
# <h2>Drawing plots<h2>

# %%
plt.figure(figsize=(10, 5))
plt.step(range(0, len(encode_arr) + 1), np.append(encode_arr, encode_arr[-1]), where='post', label="NRZ-I")
plt.axhline(y=0.5,linestyle='--',color ='r')
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.title('NRZ-L Encode')
plt.yticks([0,1])
plt.grid(True)
plt.xlim(0, len(encode_arr))  
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.step(range(0, len(decode_arr) + 1), np.append(decode_arr, decode_arr[-1]), where='post', label="NRZ-I")
plt.axhline(y=0.5,linestyle='--',color ='r')
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.title('NRZ-L Decode')
plt.yticks([0,1])
plt.grid(True)
plt.xlim(0, len(decode_arr))  
plt.show()
